# %% [markdown]
# <a href="https://colab.research.google.com/github/fjfj1970/Public/blob/main/Cap_04_Hola_mundo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# x representa los años
x = [2012, 2013, 2014, 2015, 2016, 2017]
# y representa el dinero ahorrado
y = [0, 50, 70, 70, 100, 246]

plt.plot(x, y)
plt.xlabel("Año")
plt.ylabel("Ahorro (dólares)")
plt.show()
import matplotlib.pyplot as plt

# x representa los años
x = [2017, 2018, 2019, 2020, 2021]
# y representa los terremotos
y = [1566, 1808, 1637, 1433, 2206]

plt.bar(x, y)
plt.xlabel("Año")
plt.ylabel("Terremotos")
plt.show()

# %% [markdown]
# Multiples hola mundo

# %%
nombre = "Juliana"
apellido = 'Parra'
nombreCompleto = nombre + " " + apellido

print(nombreCompleto)
print("30 años")
print(type(nombreCompleto))
# Out:
# Juliana Parra
# 30 años
# <class 'str'>

# %% [markdown]
# Nuestro primer codigo - Hola  Mundo
